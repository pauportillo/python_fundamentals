# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Actividad 16. Gráficos

# %%
#Crea una gráﬁca de barras que represente a los 10 países con  más medallas ganadas

# %%
data=pd.read_csv("C:\\Users\\aportillo\Downloads\\athlete_events.csv")
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#Ordenar que salgan solo las filas con medallas
Medallas=data[data["Medal"].notna()]
Medallas
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
cantidad=Medallas[["Year", "Season", "Medal", "NOC"]]
cantidad.head(2)
# Out:
#     Year  Season   Medal  NOC
# 3   1900  Summer    Gold  DEN
# 37  1920  Summer  Bronze  FIN

# %%
c2=pd.get_dummies(cantidad[["Medal"]])
c2.head(2)
# Out:
#     Medal_Bronze  Medal_Gold  Medal_Silver
# 3              0           1             0
# 37             1           0             0

# %%
result=pd.concat([cantidad,c2], axis=1)
result.head(2)
# Out:
#     Year  Season   Medal  NOC  Medal_Bronze  Medal_Gold  Medal_Silver
# 3   1900  Summer    Gold  DEN             0           1             0
# 37  1920  Summer  Bronze  FIN             1           0             0

# %%
cantidad2=result.groupby(["Year", "Medal", "NOC"]).sum()
cantidad2
# Out:
#                  Medal_Bronze  Medal_Gold  Medal_Silver
# Year Medal  NOC
# 1896 Bronze AUS             1           0             0
#             AUT             2           0             0
#             DEN             3           0             0
#             FRA             2           0             0
#             GBR             3           0             0
# ...                       ...         ...           ...
# 2016 Silver UKR             0           0             8
#             USA             0           0            54
#             UZB             0           0             2
#             VEN             0           0             1
#             VIE             0           0             1
#
# [3239 rows x 3 columns]

# %%
cantidad2.plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Year,Medal,NOC'>

# %%
cantidad2["Total Medals"]=cantidad2["Medal_Bronze"]+cantidad2["Medal_Gold"]+cantidad2["Medal_Silver"]
cantidad2
# Out:
#                  Medal_Bronze  Medal_Gold  Medal_Silver  Total Medals
# Year Medal  NOC
# 1896 Bronze AUS             1           0             0             1
#             AUT             2           0             0             2
#             DEN             3           0             0             3
#             FRA             2           0             0             2
#             GBR             3           0             0             3
# ...                       ...         ...           ...           ...
# 2016 Silver UKR             0           0             8             8
#             USA             0           0            54            54
#             UZB             0           0             2             2
#             VEN             0           0             1             1
#             VIE             0           0             1             1
#
# [3239 rows x 4 columns]
